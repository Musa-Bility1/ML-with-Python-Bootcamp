# %% [markdown]
# <a href="https://colab.research.google.com/github/Musa-Bility1/ML-with-Python-Bootcamp/blob/main/Weekend_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variable VS Quoted Text

# %%
# Problem 1
Liberia = 1847
print(Liberia) # The first printed 1847 because the first Liberia is a Variable, assigned a value 1847
print("Liberia") # the second printed Liberia because the Liberia is n a text quote/ a string
# Out:
# 1847
# Liberia

# %%
#Problem 2
country = "Liberia"
print(country ,"became independent in 1847")
# Out:
# Liberia became independent in 1847

# %%
# Problem 3
year = "The year is"
print(year, "1847")
# Out:
# The year is 1847

# %% [markdown]
# Variables with different Data types

# %%
#Problem 4
market_name = "Gobachop Market"
print("Market name:", market_name)
total_market_table = 150
print("Total_market_table:", total_market_table)
price_per_bag = 3200.50
print("Price_per_bag:", 3200.50)
is_market_open = True
print(is_market_open)
# Out:
# Market name: Gobachop Market
# Total_market_table: 150
# Price_per_bag: 3200.5
# True

# %%
# Problem 4 Bonus, printing type of each variable
market_name = "Gobachop Market"
print("Market_name", type(market_name))
total_market_table = 150
print("Total_market_table:", type(total_market_table))
price_per_bag = 3200.50
print("Price_per_bag:", type ( 3200.50))
is_market_open = True
print(type (is_market_open))
# Out:
# Market_name <class 'str'>
# Total_market_table: <class 'int'>
# Price_per_bag: <class 'float'>
# <class 'bool'>

# %%
# Problem 5
current_price = 2550.75
quantity = 10
total_cost = current_price * quantity
print("Total cost for", quantity, "bags:", total_cost, "LRD")
# Out:
# Total cost for 10 bags is 25507.5 LRD

# %%
# Problem 6 -Printing Boolean Variables
has_scarcity = False
is_rainy = True
print("Scarcity today", has_scarcity)
print("Rainy today", is_rainy)
# Out:
# Scarcity today False
# Rainy today True

# %% [markdown]
# Part 3: Arthmatic with Variables

# %%
# Problem 7 - claculating total revenue
price_per_bag = 800
quantity = 25
total_revenue = price_per_bag * quantity
print("Total revenue is", total_revenue, "LRD")
# Out:
# Total revenue is 20000 LRD

# %%
# Problem 8 - calculating Price increase
today_price = 3200
increase = 150
tomorrow_price = today_price + increase
print("Tomorrow price:", tomorrow_price, "LRD")
# Out:
# Tomorrow price: 3350 LRD

# %%
# Problem 9 - Splitting Cost
price_per_bag = 1800
number_of_traders = 3
cost_per_trader = 1800/3
print("Cost per trader", cost_per_trader, "LRD")
# Out:
# Cost per trader 600.0 LRD

# %%
# Problem 10 - Discount on gallon per palm oil
original_price = 2500 # Origina price
discount_rate = 0.10 #Discount rate, when converted
discount_amount = original_price * discount_rate #Multiplying the original price by the discount rate to get the discount amount.
final_price = original_price - discount_amount #Substracting the discount amount from the original to get the final price
print("Discount ampunt:", discount_price, "LRD")
print("Final price:", final_price, "LRD")
# Out:
# Discount ampunt: 250.0 LRD
# Final price: 2250.0 LRD

# %% [markdown]
# Part 4: Mixing Variables and print

# %%
# Problem 11 - Variables name vs quoted strings
item = "cassava"
price = 800
print(item) # This prints cassava because it is a variable assigned the value "cassava"
print("item") #This prints item because it is a string
print(price) # This prints 800 because price is a variable assigned a value 800
print("price") # This prints "price" because it is a string
# Out:
# cassava
# item
# 800
# price

# %%
# Problem 12 - Using variables inside message
product = "pepper"
cost = 150.50
print("One bag of",product, "cost", cost, "LRD" )
# Out:
# One bag of pepper cost 150.5 LRD

# %% [markdown]
# Bonus

# %%
# Bonus Problem
Liberia = 1847
print("Liberia became independent in", Liberia)
print("Liberia is", Liberia, "years old.")
# Out:
# Liberia became independent in 1847
# Liberia is 1847 years old.
