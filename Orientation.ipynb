# %% [markdown]
# <a href="https://colab.research.google.com/github/Musa-Bility1/ML-with-Python-Bootcamp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Example of a string

# %%
Greetings = "Whats up doctor"
print (Greetings)
# Out:
# Whats up doctor

# %% [markdown]
# Example of addition

# %%
A = 2
B = 3
c = A+B
print(c)
# Out:
# 5
