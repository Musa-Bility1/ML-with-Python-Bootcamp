# %% [markdown]
# <a href="https://colab.research.google.com/github/Musa-Bility1/ML-with-Python-Bootcamp/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# Create a labeled storage besket and put and put a number insider
tomato_price = 150
papper_price = 80

# Pull the value out of the basket
print(tomato_price)
print(papper_price)
# Out:
# 150
# 80

# %% [markdown]
# Change Tomanoe Price

# %%
tomato_price = 100
print(tomato_price)
# Out:
# 100

# %% [markdown]
# Variables(ML Anchor)

# %%
# THE CLUES (Features grouped as x)
rainfall_mm = 45.2  #clue 1
bags_available = 100 #clue 2

# THE GOAl (Targer labeled as y)
predicted_price = 3200  #What our AI calculates

print("Inputs (x):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("Output (y):", predicted_price, "LRD.")
# Out:
# Inputs (x): 45.2 mm rain, 100 bags.
# Output (y): 3200 LRD.

# %% [markdown]
# Understanding Print

# %%
Liberia = 1847
print("Liberia")
print(Liberia)
# Out:
# Liberia
# 1847

# %% [markdown]
# Date Types

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open = True

print(type(quantity))  #
print(type(price)) #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
